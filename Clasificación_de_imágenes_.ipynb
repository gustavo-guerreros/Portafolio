# %%
import zipfile


# URL DE LOS DATOS : https://www.kaggle.com/datasets/puneet6060/intel-image-classification/download?datasetVersionNumber=2
# Descomprimir el archivo
with zipfile.ZipFile('/content/DATA_IMAGEN.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, classification_report

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, classification_report

# Función para cargar las imágenes y etiquetas desde una carpeta
def load_images_and_labels_from_folder(folder):
    images = []
    labels = []
    label_to_index = {}  # Diccionario para asignar un valor numérico a cada etiqueta
    index = 0

    for subfolder in os.listdir(folder):
        subfolder_path = os.path.join(folder, subfolder)
        if os.path.isdir(subfolder_path):  # Solo considerar subcarpetas
            label_to_index[subfolder] = index
            index += 1

            for filename in os.listdir(subfolder_path):
                img = cv2.imread(os.path.join(subfolder_path, filename), cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    images.append(img)
                    labels.append(label_to_index[subfolder])  # Usar el valor numérico para la etiqueta

    return images, labels

# Cargar las imágenes y etiquetas de las carpetas seg_train y seg_test
train_images, y_train = load_images_and_labels_from_folder('/content/seg_train/seg_train')
test_images, y_test = load_images_and_labels_from_folder('/content/seg_test/seg_test')

# Preprocesar las imágenes
def preprocess_images(images):
    processed_images = []
    for img in images:
        resized_img = cv2.resize(img, (100, 100))
        processed_images.append(resized_img)
    return processed_images

train_images_processed = preprocess_images(train_images)
test_images_processed = preprocess_images(test_images)

# Convertir las imágenes a matrices numpy y normalizar los valores de los píxeles
X_train = np.array(train_images_processed) / 255.0
X_test = np.array(test_images_processed) / 255.0

# Convertir las etiquetas a categorías (one-hot encoding)
num_classes = len(set(y_train))  # Número total de clases
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

# Definir el modelo de clasificación (CNN)
model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(100, 100, 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')  # Utilizar el número de clases en el último Dense
])

# Compilar el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model.fit(X_train.reshape(-1, 100, 100, 1), y_train, epochs=10, batch_size=32)

# Evaluar el rendimiento del modelo en el conjunto de prueba
y_pred = model.predict(X_test.reshape(-1, 100, 100, 1))
y_pred = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(np.argmax(y_test, axis=1), y_pred)
report = classification_report(np.argmax(y_test, axis=1), y_pred)

print("Accuracy del modelo:", accuracy)
print("\nReporte de clasificación:\n", report)
# Out:
# Epoch 1/10
# 439/439 [==============================] - 94s 211ms/step - loss: 1.1439 - accuracy: 0.5719
# Epoch 2/10
# 439/439 [==============================] - 94s 214ms/step - loss: 0.7390 - accuracy: 0.7267
# Epoch 3/10
# 439/439 [==============================] - 90s 206ms/step - loss: 0.5497 - accuracy: 0.8033
# Epoch 4/10
# 439/439 [==============================] - 91s 208ms/step - loss: 0.3917 - accuracy: 0.8723
# Epoch 5/10
# 439/439 [==============================] - 95s 217ms/step - loss: 0.2641 - accuracy: 0.9171
# Epoch 6/10
# 439/439 [==============================] - 103s 234ms/step - loss: 0.1722 - accuracy: 0.9489
# Epoch 7/10
# 439/439 [==============================] - 97s 222ms/step - loss: 0.1273 - accuracy: 0.9676
# Epoch 8/10
# 439/439 [==============================] - 96s 218ms/step - loss: 0.0830 - accuracy: 0.9816
# Epoch 9/10
# 439/439 [==============================] - 96s 219ms/step - loss: 0.0564 - accuracy: 0.9893
# Epoch 10/10
# 439/439 [==============================] - 97s 220ms/step - loss: 0.0823 - accuracy: 0.9798
# 94/94 [==============================] - 4s 46ms/step
# Accuracy del modelo: 0.6983333333333334
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0       0.73      0.58      0.65       437
#            1       0.76      0.51      0.61       510
#            2       0.60      0.71      0.65       525
#            3       0.59      0.74      0.65       553
#            4       0.73      0.78      0.75       501
#            5       0.88      0.87      0.88       474
#
#     accuracy                           0.70      3000
#    macro avg       0.72      0.70      0.70      3000
# weighted avg       0.71      0.70      0.70      3000

# %%
import os

# Definir la ruta para guardar el modelo entrenado
ruta_modelo_entrenado = '/content/modelo_entrenado.h5'

# Verificar si el archivo ya existe y eliminarlo si es necesario
if os.path.exists(ruta_modelo_entrenado):
    os.remove(ruta_modelo_entrenado)

# Guardar el modelo entrenado en un archivo HDF5
model.save(ruta_modelo_entrenado)

print("Modelo entrenado guardado en:", ruta_modelo_entrenado)
# Out:
# Modelo entrenado guardado en: /content/modelo_entrenado.h5

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Función para cargar las imágenes desde una carpeta
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder, filename), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            images.append(img)
    return images

# Cargar el modelo entrenado
model = load_model('/content/modelo_entrenado.h5')

# Ruta de la carpeta que contiene las imágenes que deseas clasificar
pred_folder = '/content/seg_pred/seg_pred'

# Cargar las imágenes
pred_images = load_images_from_folder(pred_folder)

# Preprocesar las imágenes
def preprocess_images(images):
    processed_images = []
    for img in images:
        resized_img = cv2.resize(img, (100, 100))
        processed_images.append(resized_img)
    return processed_images

pred_images_processed = preprocess_images(pred_images)

# Convertir las imágenes a matrices numpy y normalizar los valores de los píxeles
X_pred = np.array(pred_images_processed) / 255.0

# Cargar el diccionario label_to_index utilizado durante el entrenamiento
label_to_index = {0: 'class_1', 1: 'class_2', 2: 'class_3', 3: 'class_4', 4: 'class_5', 5: 'class_6'}

# Realizar predicciones en las imágenes cargadas
y_pred = model.predict(X_pred.reshape(-1, 100, 100, 1))

# Obtener las etiquetas predichas para cada imagen
predicted_labels = np.argmax(y_pred, axis=1)

# Decodificar las etiquetas numéricas a etiquetas de clase
predicted_classes = [label_to_index[label] for label in predicted_labels]

# Imprimir las predicciones
for i, image in enumerate(pred_images):
    print(f"Imagen {i+1}: Clase predicha -> {predicted_classes[i]}")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Imagen 2302: Clase predicha -> class_5
# Imagen 2303: Clase predicha -> class_1
# Imagen 2304: Clase predicha -> class_4
# Imagen 2305: Clase predicha -> class_4
# Imagen 2306: Clase predicha -> class_4
# Imagen 2307: Clase predicha -> class_2
# Imagen 2308: Clase predicha -> class_3
# Imagen 2309: Clase predicha -> class_6
# Imagen 2310: Clase predicha -> class_3
# Imagen 2311: Clase predicha -> class_6
# Imagen 2312: Clase predicha -> class_2
# Imagen 2313: Clase predicha -> class_5
# Imagen 2314: Clase predicha -> class_6
# Imagen 2315: Clase predicha -> class_6
# Imagen 2316: Clase predicha -> class_5
# Imagen 2317: Clase predicha -> class_3
# Imagen 2318: Clase predicha -> class_4
# Imagen 2319: Clase predicha -> class_3
# Imagen 2320: Clase predicha -> class_3
# Imagen 2321: Clase predicha -> class_2
# Imagen 2322: Clase predicha -> class_4
# Imagen 2323: Clase predicha -> class_4
# Imagen 2324: Clase predicha -> class_1
# Imagen 2325: Clase predicha -> class_3
# Imagen 2326: Clase predicha -> class_4
# Imagen 2327: Clase predicha -> class_3
# Imagen 2328: Clase predicha -> class_4
# Imagen 2329: Clase predicha -> class_1
# Imagen 2330: Clase predicha -> class_4
# Imagen 2331: Clase predicha -> class_3
# Imagen 2332: Clase predicha -> class_3
# Imagen 2333: Clase predicha -> class_4
# Imagen 2334: Clase predicha -> class_1
# Imagen 2335: Clase predicha -> class_3
# Imagen 2336: Clase predicha -> class_5
# Imagen 2337: Clase predicha -> class_2
# Imagen 2338: Clase predicha -> class_1
# Imagen 2339: Clase predicha -> class_2
# Imagen 2340: Clase predicha -> class_6
# Imagen 2341: Clase predicha -> class_2
# Imagen 2342: Clase predicha -> class_2
# Imagen 2343: Clase predicha -> class_5
# Imagen 2344: Clase predicha -> class_6
# Imagen 2345: Clase predicha -> class_2
# Imagen 2346: Clase predicha -> class_3
# Imagen 2347: Clase predicha -> class_4
# Imagen 2348: Clase predicha -> class_1
# Imagen 2349: Clase predicha -> class_3
# Imagen 2350: Clase predicha -> class_3
# Imagen 2351: Clase predicha -> class_1
# Imagen 2352: Clase predicha -> class_4
# Imagen 2353: Clase predicha -> class_6
# Imagen 2354: Clase predicha -> class_3
# Imagen 2355: Clase predicha -> class_2
# Imagen 2356: Clase predicha -> class_4
# Imagen 2357: Clase predicha -> class_4
# Imagen 2358: Clase predicha -> class_5
# Imagen 2359: Clase predicha -> class_5
# Imagen 2360: Clase predicha -> class_1
# Imagen 2361: Clase predicha -> class_1
# Imagen 2362: Clase predicha -> class_3
# Imagen 2363: Clase predicha -> class_1
# Imagen 2364: Clase predicha -> class_6
# Imagen 2365: Clase predicha -> class_3
# Imagen 2366: Clase predicha -> class_6
# Imagen 2367: Clase predicha -> class_4
# Imagen 2368: Clase predicha -> class_4
# Imagen 2369: Clase predicha -> class_1
# Imagen 2370: Clase predicha -> class_6
# Imagen 2371: Clase predicha -> class_3
# Imagen 2372: Clase predicha -> class_6
# Imagen 2373: Clase predicha -> class_6
# Imagen 2374: Clase predicha -> class_6
# Imagen 2375: Clase predicha -> class_5
# Imagen 2376: Clase predicha -> class_5
# Imagen 2377: Clase predicha -> class_5
# Imagen 2378: Clase predicha -> class_3
# Imagen 2379: Clase predicha -> class_3
# Imagen 2380: Clase predicha -> class_1
# Imagen 2381: Clase predicha -> class_6
# Imagen 2382: Clase predicha -> class_5
# Imagen 2383: Clase predicha -> class_4
# Imagen 2384: Clase predicha -> class_5
# Imagen 2385: Clase predicha -> class_3
# Imagen 2386: Clase predicha -> class_6
# Imagen 2387: Clase predicha -> class_6
# Imagen 2388: Clase predicha -> class_3
# Imagen 2389: Clase predicha -> class_2
# Imagen 2390: Clase predicha -> class_4
# Imagen 2391: Clase predicha -> class_1
# Imagen 2392: Clase predicha -> class_5
# Imagen 2393: Clase predicha -> class_2
# Imagen 2394: Clase predicha -> class_1
# Imagen 2395: Clase predicha -> class_3
# Imagen 2396: Clase predicha -> class_1
# Imagen 2397: Clase predicha -> class_5
# Imagen 2398: Clase predicha -> class_6
# Imagen 2399: Clase predicha -> class_5
# Imagen 2400: Clase predicha -> class_1
# Imagen 2401: Clase predicha -> class_6
# Imagen 2402: Clase predicha -> class_3
# Imagen 2403: Clase predicha -> class_5
# Imagen 2404: Clase predicha -> class_3
# Imagen 2405: Clase predicha -> class_4
# Imagen 2406: Clase predicha -> class_4
# Imagen 2407: Clase predicha -> class_2
# Imagen 2408: Clase predicha -> class_6
# Imagen 2409: Clase predicha -> class_5
# Imagen 2410: Clase predicha -> class_4
# Imagen 2411: Clase predicha -> class_3
# Imagen 2412: Clase predicha -> class_3
# Imagen 2413: Clase predicha -> class_4
# Imagen 2414: Clase predicha -> class_4
# Imagen 2415: Clase predicha -> class_2
# Imagen 2416: Clase predicha -> class_5
# Imagen 2417: Clase predicha -> class_4
# Imagen 2418: Clase predicha -> class_5
# Imagen 2419: Clase predicha -> class_1
# Imagen 2420: Clase predicha -> class_1
# Imagen 2421: Clase predicha -> class_5
# Imagen 2422: Clase predicha -> class_6
# Imagen 2423: Clase predicha -> class_2
# Imagen 2424: Clase predicha -> class_4
# Imagen 2425: Clase predicha -> class_1
# Imagen 2426: Clase predicha -> class_1
# Imagen 2427: Clase predicha -> class_3
# Imagen 2428: Clase predicha -> class_4
# Imagen 2429: Clase predicha -> class_4
# Imagen 2430: Clase predicha -> class_6
# Imagen 2431: Clase predicha -> class_5
# Imagen 2432: Clase predicha -> class_1
# Imagen 2433: Clase predicha -> class_4
# Imagen 2434: Clase predicha -> class_6
# Imagen 2435: Clase predicha -> class_4
# Imagen 2436: Clase predicha -> class_2
# Imagen 2437: Clase predicha -> class_4
# Imagen 2438: Clase predicha -> class_6
# Imagen 2439: Clase predicha -> class_3
# Imagen 2440: Clase predicha -> class_6
# Imagen 2441: Clase predicha -> class_4
# Imagen 2442: Clase predicha -> class_2
# Imagen 2443: Clase predicha -> class_4
# Imagen 2444: Clase predicha -> class_4
# Imagen 2445: Clase predicha -> class_4
# Imagen 2446: Clase predicha -> class_5
# Imagen 2447: Clase predicha -> class_3
# Imagen 2448: Clase predicha -> class_3
# Imagen 2449: Clase predicha -> class_4
# Imagen 2450: Clase predicha -> class_6
# Imagen 2451: Clase predicha -> class_2
# Imagen 2452: Clase predicha -> class_5
# Imagen 2453: Clase predicha -> class_4
# Imagen 2454: Clase predicha -> class_5
# Imagen 2455: Clase predicha -> class_5
# Imagen 2456: Clase predicha -> class_4
# Imagen 2457: Clase predicha -> class_5
# Imagen 2458: Clase predicha -> class_4
# Imagen 2459: Clase predicha -> class_5
# Imagen 2460: Clase predicha -> class_6
# Imagen 2461: Clase predicha -> class_5
# Imagen 2462: Clase predicha -> class_3
# Imagen 2463: Clase predicha -> class_5
# Imagen 2464: Clase predicha -> class_6
# Imagen 2465: Clase predicha -> class_5
# Imagen 2466: Clase predicha -> class_4
# Imagen 2467: Clase predicha -> class_4
# Imagen 2468: Clase predicha -> class_5
# Imagen 2469: Clase predicha -> class_1
# Imagen 2470: Clase predicha -> class_1
# Imagen 2471: Clase predicha -> class_2
# Imagen 2472: Clase predicha -> class_6
# Imagen 2473: Clase predicha -> class_4
# Imagen 2474: Clase predicha -> class_4
# Imagen 2475: Clase predicha -> class_5
# Imagen 2476: Clase predicha -> class_1
# Imagen 2477: Clase predicha -> class_5
# Imagen 2478: Clase predicha -> class_6
# Imagen 2479: Clase predicha -> class_1
# Imagen 2480: Clase predicha -> class_6
# Imagen 2481: Clase predicha -> class_6
# Imagen 2482: Clase predicha -> class_4
# Imagen 2483: Clase predicha -> class_4
# Imagen 2484: Clase predicha -> class_4
# Imagen 2485: Clase predicha -> class_3
# Imagen 2486: Clase predicha -> class_1
# Imagen 2487: Clase predicha -> class_5
# Imagen 2488: Clase predicha -> class_6
# Imagen 2489: Clase predicha -> class_4
# Imagen 2490: Clase predicha -> class_3
# Imagen 2491: Clase predicha -> class_3
# Imagen 2492: Clase predicha -> class_6
# Imagen 2493: Clase predicha -> class_3
# Imagen 2494: Clase predicha -> class_6
# Imagen 2495: Clase predicha -> class_2
# Imagen 2496: Clase predicha -> class_1
# Imagen 2497: Clase predicha -> class_6
# Imagen 2498: Clase predicha -> class_6
# Imagen 2499: Clase predicha -> class_6
# Imagen 2500: Clase predicha -> class_6
# Imagen 2501: Clase predicha -> class_4
# Imagen 2502: Clase predicha -> class_3
# Imagen 2503: Clase predicha -> class_3
# Imagen 2504: Clase predicha -> class_6
# Imagen 2505: Clase predicha -> class_4
# Imagen 2506: Clase predicha -> class_4
# Imagen 2507: Clase predicha -> class_3
# Imagen 2508: Clase predicha -> class_5
# Imagen 2509: Clase predicha -> class_4
# Imagen 2510: Clase predicha -> class_6
# Imagen 2511: Clase predicha -> class_2
# Imagen 2512: Clase predicha -> class_2
# Imagen 2513: Clase predicha -> class_5
# Imagen 2514: Clase predicha -> class_4
# Imagen 2515: Clase predicha -> class_2
# Imagen 2516: Clase predicha -> class_3
# Imagen 2517: Clase predicha -> class_1
# Imagen 2518: Clase predicha -> class_1
# Imagen 2519: Clase predicha -> class_3
# Imagen 2520: Clase predicha -> class_1
# Imagen 2521: Clase predicha -> class_6
# Imagen 2522: Clase predicha -> class_5
# Imagen 2523: Clase predicha -> class_3
# Imagen 2524: Clase predicha -> class_3
# Imagen 2525: Clase predicha -> class_3
# Imagen 2526: Clase predicha -> class_2
# Imagen 2527: Clase predicha -> class_4
# Imagen 2528: Clase predicha -> class_4
# Imagen 2529: Clase predicha -> class_1
# Imagen 2530: Clase predicha -> class_3
# Imagen 2531: Clase predicha -> class_4
# Imagen 2532: Clase predicha -> class_6
# Imagen 2533: Clase predicha -> class_5
# Imagen 2534: Clase predicha -> class_5
# Imagen 2535: Clase predicha -> class_4
# Imagen 2536: Clase predicha -> class_2
# Imagen 2537: Clase predicha -> class_4
# Imagen 2538: Clase predicha -> class_3
# Imagen 2539: Clase predicha -> class_4
# Imagen 2540: Clase predicha -> class_5
# Imagen 2541: Clase predicha -> class_3
# Imagen 2542: Clase predicha -> class_3
# Imagen 2543: Clase predicha -> class_3
# Imagen 2544: Clase predicha -> class_2
# Imagen 2545: Clase predicha -> class_6
# Imagen 2546: Clase predicha -> class_4
# Imagen 2547: Clase predicha -> class_3
# Imagen 2548: Clase predicha -> class_2
# Imagen 2549: Clase predicha -> class_5
# Imagen 2550: Clase predicha -> class_4
# Imagen 2551: Clase predicha -> class_5
# Imagen 2552: Clase predicha -> class_1
# Imagen 2553: Clase predicha -> class_4
# Imagen 2554: Clase predicha -> class_6
# Imagen 2555: Clase predicha -> class_2
# Imagen 2556: Clase predicha -> class_6
# Imagen 2557: Clase predicha -> class_3
# Imagen 2558: Clase predicha -> class_4
# Imagen 2559: Clase predicha -> class_5
# Imagen 2560: Clase predicha -> class_3
# Imagen 2561: Clase predicha -> class_5
# Imagen 2562: Clase predicha -> class_6
# Imagen 2563: Clase predicha -> class_4
# Imagen 2564: Clase predicha -> class_4
# Imagen 2565: Clase predicha -> class_2
# Imagen 2566: Clase predicha -> class_5
# Imagen 2567: Clase predicha -> class_5
# Imagen 2568: Clase predicha -> class_3
# Imagen 2569: Clase predicha -> class_5
# Imagen 2570: Clase predicha -> class_6
# Imagen 2571: Clase predicha -> class_3
# Imagen 2572: Clase predicha -> class_2
# Imagen 2573: Clase predicha -> class_1
# Imagen 2574: Clase predicha -> class_4
# Imagen 2575: Clase predicha -> class_5
# Imagen 2576: Clase predicha -> class_4
# Imagen 2577: Clase predicha -> class_1
# Imagen 2578: Clase predicha -> class_5
# Imagen 2579: Clase predicha -> class_1
# Imagen 2580: Clase predicha -> class_6
# Imagen 2581: Clase predicha -> class_3
# Imagen 2582: Clase predicha -> class_5
# Imagen 2583: Clase predicha -> class_5
# Imagen 2584: Clase predicha -> class_1
# Imagen 2585: Clase predicha -> class_6
# Imagen 2586: Clase predicha -> class_3
# Imagen 2587: Clase predicha -> class_3
# Imagen 2588: Clase predicha -> class_2
# Imagen 2589: Clase predicha -> class_4
# Imagen 2590: Clase predicha -> class_6
# Imagen 2591: Clase predicha -> class_4
# Imagen 2592: Clase predicha -> class_6
# Imagen 2593: Clase predicha -> class_5
# Imagen 2594: Clase predicha -> class_1
# Imagen 2595: Clase predicha -> class_2
# Imagen 2596: Clase predicha -> class_1
# Imagen 2597: Clase predicha -> class_5
# Imagen 2598: Clase predicha -> class_6
# Imagen 2599: Clase predicha -> class_4
# Imagen 2600: Clase predicha -> class_2
# Imagen 2601: Clase predicha -> class_1
# Imagen 2602: Clase predicha -> class_3
# Imagen 2603: Clase predicha -> class_2
# Imagen 2604: Clase predicha -> class_2
# Imagen 2605: Clase predicha -> class_5
# Imagen 2606: Clase predicha -> class_2
# Imagen 2607: Clase predicha -> class_4
# Imagen 2608: Clase predicha -> class_5
# Imagen 2609: Clase predicha -> class_6
# Imagen 2610: Clase predicha -> class_4
# Imagen 2611: Clase predicha -> class_4
# Imagen 2612: Clase predicha -> class_3
# Imagen 2613: Clase predicha -> class_3
# Imagen 2614: Clase predicha -> class_3
# Imagen 2615: Clase predicha -> class_3
# Imagen 2616: Clase predicha -> class_3
# Imagen 2617: Clase predicha -> class_4
# Imagen 2618: Clase predicha -> class_3
# Imagen 2619: Clase predicha -> class_4
# Imagen 2620: Clase predicha -> class_2
# Imagen 2621: Clase predicha -> class_6
# Imagen 2622: Clase predicha -> class_4
# Imagen 2623: Clase predicha -> class_1
# Imagen 2624: Clase predicha -> class_6
# Imagen 2625: Clase predicha -> class_4
# Imagen 2626: Clase predicha -> class_1
# Imagen 2627: Clase predicha -> class_4
# Imagen 2628: Clase predicha -> class_4
# Imagen 2629: Clase predicha -> class_3
# Imagen 2630: Clase predicha -> class_6
# Imagen 2631: Clase predicha -> class_2
# Imagen 2632: Clase predicha -> class_2
# Imagen 2633: Clase predicha -> class_4
# Imagen 2634: Clase predicha -> class_4
# Imagen 2635: Clase predicha -> class_4
# Imagen 2636: Clase predicha -> class_5
# Imagen 2637: Clase predicha -> class_4
# Imagen 2638: Clase predicha -> class_6
# Imagen 2639: Clase predicha -> class_3
# Imagen 2640: Clase predicha -> class_3
# Imagen 2641: Clase predicha -> class_3
# Imagen 2642: Clase predicha -> class_3
# Imagen 2643: Clase predicha -> class_4
# Imagen 2644: Clase predicha -> class_3
# Imagen 2645: Clase predicha -> class_1
# Imagen 2646: Clase predicha -> class_2
# Imagen 2647: Clase predicha -> class_4
# Imagen 2648: Clase predicha -> class_4
# Imagen 2649: Clase predicha -> class_4
# Imagen 2650: Clase predicha -> class_4
# Imagen 2651: Clase predicha -> class_6
# Imagen 2652: Clase predicha -> class_4
# Imagen 2653: Clase predicha -> class_1
# Imagen 2654: Clase predicha -> class_3
# Imagen 2655: Clase predicha -> class_6
# Imagen 2656: Clase predicha -> class_4
# Imagen 2657: Clase predicha -> class_6
# Imagen 2658: Clase predicha -> class_2
# Imagen 2659: Clase predicha -> class_3
# Imagen 2660: Clase predicha -> class_5
# Imagen 2661: Clase predicha -> class_3
# Imagen 2662: Clase predicha -> class_1
# Imagen 2663: Clase predicha -> class_1
# Imagen 2664: Clase predicha -> class_6
# Imagen 2665: Clase predicha -> class_3
# Imagen 2666: Clase predicha -> class_3
# Imagen 2667: Clase predicha -> class_6
# Imagen 2668: Clase predicha -> class_2
# Imagen 2669: Clase predicha -> class_1
# Imagen 2670: Clase predicha -> class_1
# Imagen 2671: Clase predicha -> class_2
# Imagen 2672: Clase predicha -> class_4
# Imagen 2673: Clase predicha -> class_2
# Imagen 2674: Clase predicha -> class_2
# Imagen 2675: Clase predicha -> class_6
# Imagen 2676: Clase predicha -> class_6
# Imagen 2677: Clase predicha -> class_1
# Imagen 2678: Clase predicha -> class_3
# Imagen 2679: Clase predicha -> class_2
# Imagen 2680: Clase predicha -> class_5
# Imagen 2681: Clase predicha -> class_2
# Imagen 2682: Clase predicha -> class_6
# Imagen 2683: Clase predicha -> class_4
# Imagen 2684: Clase predicha -> class_4
# Imagen 2685: Clase predicha -> class_2
# Imagen 2686: Clase predicha -> class_5
# Imagen 2687: Clase predicha -> class_1
# Imagen 2688: Clase predicha -> class_2
# Imagen 2689: Clase predicha -> class_2
# Imagen 2690: Clase predicha -> class_1
# Imagen 2691: Clase predicha -> class_3
# Imagen 2692: Clase predicha -> class_5
# Imagen 2693: Clase predicha -> class_1
# Imagen 2694: Clase predicha -> class_3
# Imagen 2695: Clase predicha -> class_5
# Imagen 2696: Clase predicha -> class_5
# Imagen 2697: Clase predicha -> class_6
# Imagen 2698: Clase predicha -> class_5
# Imagen 2699: Clase predicha -> class_3
# Imagen 2700: Clase predicha -> class_2
# Imagen 2701: Clase predicha -> class_1
# Imagen 2702: Clase predicha -> class_2
# Imagen 2703: Clase predicha -> class_4
# Imagen 2704: Clase predicha -> class_1
# Imagen 2705: Clase predicha -> class_2
# Imagen 2706: Clase predicha -> class_3
# Imagen 2707: Clase predicha -> class_1
# Imagen 2708: Clase predicha -> class_5
# Imagen 2709: Clase predicha -> class_6
# Imagen 2710: Clase predicha -> class_2
# Imagen 2711: Clase predicha -> class_3
# Imagen 2712: Clase predicha -> class_5
# Imagen 2713: Clase predicha -> class_5
# Imagen 2714: Clase predicha -> class_3
# Imagen 2715: Clase predicha -> class_1
# Imagen 2716: Clase predicha -> class_1
# Imagen 2717: Clase predicha -> class_1
# Imagen 2718: Clase predicha -> class_3
# Imagen 2719: Clase predicha -> class_1
# Imagen 2720: Clase predicha -> class_1
# Imagen 2721: Clase predicha -> class_4
# Imagen 2722: Clase predicha -> class_2
# Imagen 2723: Clase predicha -> class_5
# Imagen 2724: Clase predicha -> class_5
# Imagen 2725: Clase predicha -> class_4
# Imagen 2726: Clase predicha -> class_5
# Imagen 2727: Clase predicha -> class_3
# Imagen 2728: Clase predicha -> class_5
# Imagen 2729: Clase predicha -> class_6
# Imagen 2730: Clase predicha -> class_6
# Imagen 2731: Clase predicha -> class_2
# Imagen 2732: Clase predicha -> class_2
# Imagen 2733: Clase predicha -> class_2
# Imagen 2734: Clase predicha -> class_3
# Imagen 2735: Clase predicha -> class_4
# Imagen 2736: Clase predicha -> class_6
# Imagen 2737: Clase predicha -> class_4
# Imagen 2738: Clase predicha -> class_4
# Imagen 2739: Clase predicha -> class_1
# Imagen 2740: Clase predicha -> class_4
# Imagen 2741: Clase predicha -> class_2
# Imagen 2742: Clase predicha -> class_2
# Imagen 2743: Clase predicha -> class_6
# Imagen 2744: Clase predicha -> class_2
# Imagen 2745: Clase predicha -> class_1
# Imagen 2746: Clase predicha -> class_5
# Imagen 2747: Clase predicha -> class_4
# Imagen 2748: Clase predicha -> class_4
# Imagen 2749: Clase predicha -> class_2
# Imagen 2750: Clase predicha -> class_4
# Imagen 2751: Clase predicha -> class_1
# Imagen 2752: Clase predicha -> class_5
# Imagen 2753: Clase predicha -> class_5
# Imagen 2754: Clase predicha -> class_3
# Imagen 2755: Clase predicha -> class_6
# Imagen 2756: Clase predicha -> class_1
# Imagen 2757: Clase predicha -> class_4
# Imagen 2758: Clase predicha -> class_6
# Imagen 2759: Clase predicha -> class_3
# Imagen 2760: Clase predicha -> class_2
# Imagen 2761: Clase predicha -> class_4
# Imagen 2762: Clase predicha -> class_3
# Imagen 2763: Clase predicha -> class_1
# Imagen 2764: Clase predicha -> class_5
# Imagen 2765: Clase predicha -> class_6
# Imagen 2766: Clase predicha -> class_3
# Imagen 2767: Clase predicha -> class_4
# Imagen 2768: Clase predicha -> class_5
# Imagen 2769: Clase predicha -> class_3
# Imagen 2770: Clase predicha -> class_3
# Imagen 2771: Clase predicha -> class_5
# Imagen 2772: Clase predicha -> class_4
# Imagen 2773: Clase predicha -> class_1
# Imagen 2774: Clase predicha -> class_1
# Imagen 2775: Clase predicha -> class_5
# Imagen 2776: Clase predicha -> class_4
# Imagen 2777: Clase predicha -> class_6
# Imagen 2778: Clase predicha -> class_3
# Imagen 2779: Clase predicha -> class_6
# Imagen 2780: Clase predicha -> class_1
# Imagen 2781: Clase predicha -> class_5
# Imagen 2782: Clase predicha -> class_1
# Imagen 2783: Clase predicha -> class_2
# Imagen 2784: Clase predicha -> class_1
# Imagen 2785: Clase predicha -> class_5
# Imagen 2786: Clase predicha -> class_6
# Imagen 2787: Clase predicha -> class_1
# Imagen 2788: Clase predicha -> class_6
# Imagen 2789: Clase predicha -> class_1
# Imagen 2790: Clase predicha -> class_3
# Imagen 2791: Clase predicha -> class_3
# Imagen 2792: Clase predicha -> class_2
# Imagen 2793: Clase predicha -> class_6
# Imagen 2794: Clase predicha -> class_3
# Imagen 2795: Clase predicha -> class_3
# Imagen 2796: Clase predicha -> class_3
# Imagen 2797: Clase predicha -> class_3
# Imagen 2798: Clase predicha -> class_2
# Imagen 2799: Clase predicha -> class_5
# Imagen 2800: Clase predicha -> class_3
# Imagen 2801: Clase predicha -> class_5
# Imagen 2802: Clase predicha -> class_3
# Imagen 2803: Clase predicha -> class_5
# Imagen 2804: Clase predicha -> class_6
# Imagen 2805: Clase predicha -> class_3
# Imagen 2806: Clase predicha -> class_4
# Imagen 2807: Clase predicha -> class_5
# Imagen 2808: Clase predicha -> class_4
# Imagen 2809: Clase predicha -> class_3
# Imagen 2810: Clase predicha -> class_4
# Imagen 2811: Clase predicha -> class_4
# Imagen 2812: Clase predicha -> class_5
# Imagen 2813: Clase predicha -> class_3
# Imagen 2814: Clase predicha -> class_5
# Imagen 2815: Clase predicha -> class_2
# Imagen 2816: Clase predicha -> class_6
# Imagen 2817: Clase predicha -> class_5
# Imagen 2818: Clase predicha -> class_5
# Imagen 2819: Clase predicha -> class_4
# Imagen 2820: Clase predicha -> class_5
# Imagen 2821: Clase predicha -> class_2
# Imagen 2822: Clase predicha -> class_3
# Imagen 2823: Clase predicha -> class_3
# Imagen 2824: Clase predicha -> class_4
# Imagen 2825: Clase predicha -> class_5
# Imagen 2826: Clase predicha -> class_3
# Imagen 2827: Clase predicha -> class_4
# Imagen 2828: Clase predicha -> class_4
# Imagen 2829: Clase predicha -> class_6
# Imagen 2830: Clase predicha -> class_5
# Imagen 2831: Clase predicha -> class_4
# Imagen 2832: Clase predicha -> class_4
# Imagen 2833: Clase predicha -> class_4
# Imagen 2834: Clase predicha -> class_3
# Imagen 2835: Clase predicha -> class_5
# Imagen 2836: Clase predicha -> class_6
# Imagen 2837: Clase predicha -> class_2
# Imagen 2838: Clase predicha -> class_2
# Imagen 2839: Clase predicha -> class_2
# Imagen 2840: Clase predicha -> class_3
# Imagen 2841: Clase predicha -> class_4
# Imagen 2842: Clase predicha -> class_3
# Imagen 2843: Clase predicha -> class_5
# Imagen 2844: Clase predicha -> class_3
# Imagen 2845: Clase predicha -> class_1
# Imagen 2846: Clase predicha -> class_4
# Imagen 2847: Clase predicha -> class_2
# Imagen 2848: Clase predicha -> class_2
# Imagen 2849: Clase predicha -> class_2
# Imagen 2850: Clase predicha -> class_3
# Imagen 2851: Clase predicha -> class_6
# Imagen 2852: Clase predicha -> class_3
# Imagen 2853: Clase predicha -> class_5
# Imagen 2854: Clase predicha -> class_5
# Imagen 2855: Clase predicha -> class_1
# Imagen 2856: Clase predicha -> class_2
# Imagen 2857: Clase predicha -> class_3
# Imagen 2858: Clase predicha -> class_4
# Imagen 2859: Clase predicha -> class_1
# Imagen 2860: Clase predicha -> class_4
# Imagen 2861: Clase predicha -> class_1
# Imagen 2862: Clase predicha -> class_2
# Imagen 2863: Clase predicha -> class_3
# Imagen 2864: Clase predicha -> class_3
# Imagen 2865: Clase predicha -> class_4
# Imagen 2866: Clase predicha -> class_6
# Imagen 2867: Clase predicha -> class_4
# Imagen 2868: Clase predicha -> class_4
# Imagen 2869: Clase predicha -> class_3
# Imagen 2870: Clase predicha -> class_5
# Imagen 2871: Clase predicha -> class_4
# Imagen 2872: Clase predicha -> class_6
# Imagen 2873: Clase predicha -> class_2
# Imagen 2874: Clase predicha -> class_3
# Imagen 2875: Clase predicha -> class_3
# Imagen 2876: Clase predicha -> class_5
# Imagen 2877: Clase predicha -> class_1
# Imagen 2878: Clase predicha -> class_1
# Imagen 2879: Clase predicha -> class_1
# Imagen 2880: Clase predicha -> class_1
# Imagen 2881: Clase predicha -> class_2
# Imagen 2882: Clase predicha -> class_1
# Imagen 2883: Clase predicha -> class_3
# Imagen 2884: Clase predicha -> class_3
# Imagen 2885: Clase predicha -> class_5
# Imagen 2886: Clase predicha -> class_6
# Imagen 2887: Clase predicha -> class_2
# Imagen 2888: Clase predicha -> class_4
# Imagen 2889: Clase predicha -> class_5
# Imagen 2890: Clase predicha -> class_4
# Imagen 2891: Clase predicha -> class_5
# Imagen 2892: Clase predicha -> class_1
# Imagen 2893: Clase predicha -> class_4
# Imagen 2894: Clase predicha -> class_3
# Imagen 2895: Clase predicha -> class_4
# Imagen 2896: Clase predicha -> class_4
# Imagen 2897: Clase predicha -> class_4
# Imagen 2898: Clase predicha -> class_1
# Imagen 2899: Clase predicha -> class_1
# Imagen 2900: Clase predicha -> class_3
# Imagen 2901: Clase predicha -> class_4
# Imagen 2902: Clase predicha -> class_6
# Imagen 2903: Clase predicha -> class_4
# Imagen 2904: Clase predicha -> class_2
# Imagen 2905: Clase predicha -> class_4
# Imagen 2906: Clase predicha -> class_5
# Imagen 2907: Clase predicha -> class_2
# Imagen 2908: Clase predicha -> class_5
# Imagen 2909: Clase predicha -> class_1
# Imagen 2910: Clase predicha -> class_4
# Imagen 2911: Clase predicha -> class_2
# Imagen 2912: Clase predicha -> class_3
# Imagen 2913: Clase predicha -> class_5
# Imagen 2914: Clase predicha -> class_6
# Imagen 2915: Clase predicha -> class_6
# Imagen 2916: Clase predicha -> class_3
# Imagen 2917: Clase predicha -> class_3
# Imagen 2918: Clase predicha -> class_3
# Imagen 2919: Clase predicha -> class_4
# Imagen 2920: Clase predicha -> class_1
# Imagen 2921: Clase predicha -> class_4
# Imagen 2922: Clase predicha -> class_4
# Imagen 2923: Clase predicha -> class_5
# Imagen 2924: Clase predicha -> class_1
# Imagen 2925: Clase predicha -> class_1
# Imagen 2926: Clase predicha -> class_6
# Imagen 2927: Clase predicha -> class_5
# Imagen 2928: Clase predicha -> class_6
# Imagen 2929: Clase predicha -> class_1
# Imagen 2930: Clase predicha -> class_3
# Imagen 2931: Clase predicha -> class_5
# Imagen 2932: Clase predicha -> class_6
# Imagen 2933: Clase predicha -> class_1
# Imagen 2934: Clase predicha -> class_5
# Imagen 2935: Clase predicha -> class_4
# Imagen 2936: Clase predicha -> class_6
# Imagen 2937: Clase predicha -> class_3
# Imagen 2938: Clase predicha -> class_3
# Imagen 2939: Clase predicha -> class_4
# Imagen 2940: Clase predicha -> class_5
# Imagen 2941: Clase predicha -> class_4
# Imagen 2942: Clase predicha -> class_3
# Imagen 2943: Clase predicha -> class_4
# Imagen 2944: Clase predicha -> class_3
# Imagen 2945: Clase predicha -> class_2
# Imagen 2946: Clase predicha -> class_3
# Imagen 2947: Clase predicha -> class_5
# Imagen 2948: Clase predicha -> class_4
# Imagen 2949: Clase predicha -> class_6
# Imagen 2950: Clase predicha -> class_2
# Imagen 2951: Clase predicha -> class_1
# Imagen 2952: Clase predicha -> class_3
# Imagen 2953: Clase predicha -> class_3
# Imagen 2954: Clase predicha -> class_5
# Imagen 2955: Clase predicha -> class_3
# Imagen 2956: Clase predicha -> class_5
# Imagen 2957: Clase predicha -> class_4
# Imagen 2958: Clase predicha -> class_3
# Imagen 2959: Clase predicha -> class_5
# Imagen 2960: Clase predicha -> class_3
# Imagen 2961: Clase predicha -> class_6
# Imagen 2962: Clase predicha -> class_4
# Imagen 2963: Clase predicha -> class_4
# Imagen 2964: Clase predicha -> class_1
# Imagen 2965: Clase predicha -> class_2
# Imagen 2966: Clase predicha -> class_6
# Imagen 2967: Clase predicha -> class_5
# Imagen 2968: Clase predicha -> class_4
# Imagen 2969: Clase predicha -> class_1
# Imagen 2970: Clase predicha -> class_6
# Imagen 2971: Clase predicha -> class_1
# Imagen 2972: Clase predicha -> class_2
# Imagen 2973: Clase predicha -> class_5
# Imagen 2974: Clase predicha -> class_1
# Imagen 2975: Clase predicha -> class_1
# Imagen 2976: Clase predicha -> class_6
# Imagen 2977: Clase predicha -> class_5
# Imagen 2978: Clase predicha -> class_5
# Imagen 2979: Clase predicha -> class_6
# Imagen 2980: Clase predicha -> class_6
# Imagen 2981: Clase predicha -> class_1
# Imagen 2982: Clase predicha -> class_1
# Imagen 2983: Clase predicha -> class_5
# Imagen 2984: Clase predicha -> class_6
# Imagen 2985: Clase predicha -> class_6
# Imagen 2986: Clase predicha -> class_4
# Imagen 2987: Clase predicha -> class_4
# Imagen 2988: Clase predicha -> class_1
# Imagen 2989: Clase predicha -> class_6
# Imagen 2990: Clase predicha -> class_6
# Imagen 2991: Clase predicha -> class_1
# Imagen 2992: Clase predicha -> class_4
# Imagen 2993: Clase predicha -> class_6
# Imagen 2994: Clase predicha -> class_6
# Imagen 2995: Clase predicha -> class_1
# Imagen 2996: Clase predicha -> class_2
# Imagen 2997: Clase predicha -> class_2
# Imagen 2998: Clase predicha -> class_1
# Imagen 2999: Clase predicha -> class_3
# Imagen 3000: Clase predicha -> class_1
# Imagen 3001: Clase predicha -> class_5
# Imagen 3002: Clase predicha -> class_1
# Imagen 3003: Clase predicha -> class_2
# Imagen 3004: Clase predicha -> class_6
# Imagen 3005: Clase predicha -> class_6
# Imagen 3006: Clase predicha -> class_5
# Imagen 3007: Clase predicha -> class_4
# Imagen 3008: Clase predicha -> class_4
# Imagen 3009: Clase predicha -> class_4
# Imagen 3010: Clase predicha -> class_1
# Imagen 3011: Clase predicha -> class_3
# Imagen 3012: Clase predicha -> class_3
# Imagen 3013: Clase predicha -> class_6
# Imagen 3014: Clase predicha -> class_5
# Imagen 3015: Clase predicha -> class_2
# Imagen 3016: Clase predicha -> class_6
# Imagen 3017: Clase predicha -> class_3
# Imagen 3018: Clase predicha -> class_2
# Imagen 3019: Clase predicha -> class_3
# Imagen 3020: Clase predicha -> class_1
# Imagen 3021: Clase predicha -> class_4
# Imagen 3022: Clase predicha -> class_3
# Imagen 3023: Clase predicha -> class_4
# Imagen 3024: Clase predicha -> class_3
# Imagen 3025: Clase predicha -> class_4
# Imagen 3026: Clase predicha -> class_5
# Imagen 3027: Clase predicha -> class_6
# Imagen 3028: Clase predicha -> class_2
# Imagen 3029: Clase predicha -> class_2
# Imagen 3030: Clase predicha -> class_6
# Imagen 3031: Clase predicha -> class_6
# Imagen 3032: Clase predicha -> class_1
# Imagen 3033: Clase predicha -> class_4
# Imagen 3034: Clase predicha -> class_4
# Imagen 3035: Clase predicha -> class_5
# Imagen 3036: Clase predicha -> class_1
# Imagen 3037: Clase predicha -> class_6
# Imagen 3038: Clase predicha -> class_5
# Imagen 3039: Clase predicha -> class_6
# Imagen 3040: Clase predicha -> class_1
# Imagen 3041: Clase predicha -> class_6
# Imagen 3042: Clase predicha -> class_2
# Imagen 3043: Clase predicha -> class_4
# Imagen 3044: Clase predicha -> class_5
# Imagen 3045: Clase predicha -> class_5
# Imagen 3046: Clase predicha -> class_5
# Imagen 3047: Clase predicha -> class_1
# Imagen 3048: Clase predicha -> class_4
# Imagen 3049: Clase predicha -> class_1
# Imagen 3050: Clase predicha -> class_5
# Imagen 3051: Clase predicha -> class_5
# Imagen 3052: Clase predicha -> class_5
# Imagen 3053: Clase predicha -> class_5
# Imagen 3054: Clase predicha -> class_3
# Imagen 3055: Clase predicha -> class_3
# Imagen 3056: Clase predicha -> class_2
# Imagen 3057: Clase predicha -> class_4
# Imagen 3058: Clase predicha -> class_2
# Imagen 3059: Clase predicha -> class_5
# Imagen 3060: Clase predicha -> class_3
# Imagen 3061: Clase predicha -> class_3
# Imagen 3062: Clase predicha -> class_5
# Imagen 3063: Clase predicha -> class_6
# Imagen 3064: Clase predicha -> class_5
# Imagen 3065: Clase predicha -> class_4
# Imagen 3066: Clase predicha -> class_6
# Imagen 3067: Clase predicha -> class_5
# Imagen 3068: Clase predicha -> class_5
# Imagen 3069: Clase predicha -> class_4
# Imagen 3070: Clase predicha -> class_6
# Imagen 3071: Clase predicha -> class_4
# Imagen 3072: Clase predicha -> class_1
# Imagen 3073: Clase predicha -> class_1
# Imagen 3074: Clase predicha -> class_4
# Imagen 3075: Clase predicha -> class_5
# Imagen 3076: Clase predicha -> class_1
# Imagen 3077: Clase predicha -> class_2
# Imagen 3078: Clase predicha -> class_1
# Imagen 3079: Clase predicha -> class_5
# Imagen 3080: Clase predicha -> class_2
# Imagen 3081: Clase predicha -> class_3
# Imagen 3082: Clase predicha -> class_3
# Imagen 3083: Clase predicha -> class_4
# Imagen 3084: Clase predicha -> class_1
# Imagen 3085: Clase predicha -> class_3
# Imagen 3086: Clase predicha -> class_3
# Imagen 3087: Clase predicha -> class_3
# Imagen 3088: Clase predicha -> class_3
# Imagen 3089: Clase predicha -> class_2
# Imagen 3090: Clase predicha -> class_3
# Imagen 3091: Clase predicha -> class_1
# Imagen 3092: Clase predicha -> class_3
# Imagen 3093: Clase predicha -> class_6
# Imagen 3094: Clase predicha -> class_5
# Imagen 3095: Clase predicha -> class_5
# Imagen 3096: Clase predicha -> class_6
# Imagen 3097: Clase predicha -> class_3
# Imagen 3098: Clase predicha -> class_4
# Imagen 3099: Clase predicha -> class_3
# Imagen 3100: Clase predicha -> class_4
# Imagen 3101: Clase predicha -> class_4
# Imagen 3102: Clase predicha -> class_4
# Imagen 3103: Clase predicha -> class_5
# Imagen 3104: Clase predicha -> class_5
# Imagen 3105: Clase predicha -> class_6
# Imagen 3106: Clase predicha -> class_4
# Imagen 3107: Clase predicha -> class_5
# Imagen 3108: Clase predicha -> class_6
# Imagen 3109: Clase predicha -> class_6
# Imagen 3110: Clase predicha -> class_4
# Imagen 3111: Clase predicha -> class_3
# Imagen 3112: Clase predicha -> class_5
# Imagen 3113: Clase predicha -> class_3
# Imagen 3114: Clase predicha -> class_2
# Imagen 3115: Clase predicha -> class_6
# Imagen 3116: Clase predicha -> class_5
# Imagen 3117: Clase predicha -> class_1
# Imagen 3118: Clase predicha -> class_4
# Imagen 3119: Clase predicha -> class_3
# Imagen 3120: Clase predicha -> class_3
# Imagen 3121: Clase predicha -> class_3
# Imagen 3122: Clase predicha -> class_4
# Imagen 3123: Clase predicha -> class_4
# Imagen 3124: Clase predicha -> class_5
# Imagen 3125: Clase predicha -> class_5
# Imagen 3126: Clase predicha -> class_4
# Imagen 3127: Clase predicha -> class_3
# Imagen 3128: Clase predicha -> class_3
# Imagen 3129: Clase predicha -> class_6
# Imagen 3130: Clase predicha -> class_1
# Imagen 3131: Clase predicha -> class_1
# Imagen 3132: Clase predicha -> class_5
# Imagen 3133: Clase predicha -> class_3
# Imagen 3134: Clase predicha -> class_1
# Imagen 3135: Clase predicha -> class_5
# Imagen 3136: Clase predicha -> class_4
# Imagen 3137: Clase predicha -> class_4
# Imagen 3138: Clase predicha -> class_1
# Imagen 3139: Clase predicha -> class_5
# Imagen 3140: Clase predicha -> class_5
# Imagen 3141: Clase predicha -> class_4
# Imagen 3142: Clase predicha -> class_1
# Imagen 3143: Clase predicha -> class_4
# Imagen 3144: Clase predicha -> class_1
# Imagen 3145: Clase predicha -> class_2
# Imagen 3146: Clase predicha -> class_4
# Imagen 3147: Clase predicha -> class_3
# Imagen 3148: Clase predicha -> class_6
# Imagen 3149: Clase predicha -> class_2
# Imagen 3150: Clase predicha -> class_3
# Imagen 3151: Clase predicha -> class_6
# Imagen 3152: Clase predicha -> class_4
# Imagen 3153: Clase predicha -> class_4
# Imagen 3154: Clase predicha -> class_5
# Imagen 3155: Clase predicha -> class_3
# Imagen 3156: Clase predicha -> class_1
# Imagen 3157: Clase predicha -> class_3
# Imagen 3158: Clase predicha -> class_5
# Imagen 3159: Clase predicha -> class_3
# Imagen 3160: Clase predicha -> class_1
# Imagen 3161: Clase predicha -> class_6
# Imagen 3162: Clase predicha -> class_6
# Imagen 3163: Clase predicha -> class_4
# Imagen 3164: Clase predicha -> class_5
# Imagen 3165: Clase predicha -> class_5
# Imagen 3166: Clase predicha -> class_5
# Imagen 3167: Clase predicha -> class_6
# Imagen 3168: Clase predicha -> class_3
# Imagen 3169: Clase predicha -> class_2
# Imagen 3170: Clase predicha -> class_3
# Imagen 3171: Clase predicha -> class_6
# Imagen 3172: Clase predicha -> class_3
# Imagen 3173: Clase predicha -> class_4
# Imagen 3174: Clase predicha -> class_6
# Imagen 3175: Clase predicha -> class_6
# Imagen 3176: Clase predicha -> class_4
# Imagen 3177: Clase predicha -> class_3
# Imagen 3178: Clase predicha -> class_6
# Imagen 3179: Clase predicha -> class_5
# Imagen 3180: Clase predicha -> class_4
# Imagen 3181: Clase predicha -> class_3
# Imagen 3182: Clase predicha -> class_1
# Imagen 3183: Clase predicha -> class_2
# Imagen 3184: Clase predicha -> class_5
# Imagen 3185: Clase predicha -> class_6
# Imagen 3186: Clase predicha -> class_3
# Imagen 3187: Clase predicha -> class_1
# Imagen 3188: Clase predicha -> class_5
# Imagen 3189: Clase predicha -> class_6
# Imagen 3190: Clase predicha -> class_6
# Imagen 3191: Clase predicha -> class_1
# Imagen 3192: Clase predicha -> class_1
# Imagen 3193: Clase predicha -> class_5
# Imagen 3194: Clase predicha -> class_5
# Imagen 3195: Clase predicha -> class_3
# Imagen 3196: Clase predicha -> class_5
# Imagen 3197: Clase predicha -> class_6
# Imagen 3198: Clase predicha -> class_2
# Imagen 3199: Clase predicha -> class_1
# Imagen 3200: Clase predicha -> class_4
# Imagen 3201: Clase predicha -> class_3
# Imagen 3202: Clase predicha -> class_5
# Imagen 3203: Clase predicha -> class_3
# Imagen 3204: Clase predicha -> class_5
# Imagen 3205: Clase predicha -> class_4
# Imagen 3206: Clase predicha -> class_3
# Imagen 3207: Clase predicha -> class_3
# Imagen 3208: Clase predicha -> class_5
# Imagen 3209: Clase predicha -> class_5
# Imagen 3210: Clase predicha -> class_5
# Imagen 3211: Clase predicha -> class_5
# Imagen 3212: Clase predicha -> class_6
# Imagen 3213: Clase predicha -> class_4
# Imagen 3214: Clase predicha -> class_2
# Imagen 3215: Clase predicha -> class_4
# Imagen 3216: Clase predicha -> class_2
# Imagen 3217: Clase predicha -> class_3
# Imagen 3218: Clase predicha -> class_2
# Imagen 3219: Clase predicha -> class_6
# Imagen 3220: Clase predicha -> class_6
# Imagen 3221: Clase predicha -> class_5
# Imagen 3222: Clase predicha -> class_5
# Imagen 3223: Clase predicha -> class_4
# Imagen 3224: Clase predicha -> class_4
# Imagen 3225: Clase predicha -> class_3
# Imagen 3226: Clase predicha -> class_3
# Imagen 3227: Clase predicha -> class_5
# Imagen 3228: Clase predicha -> class_4
# Imagen 3229: Clase predicha -> class_6
# Imagen 3230: Clase predicha -> class_6
# Imagen 3231: Clase predicha -> class_4
# Imagen 3232: Clase predicha -> class_5
# Imagen 3233: Clase predicha -> class_1
# Imagen 3234: Clase predicha -> class_4
# Imagen 3235: Clase predicha -> class_5
# Imagen 3236: Clase predicha -> class_3
# Imagen 3237: Clase predicha -> class_4
# Imagen 3238: Clase predicha -> class_5
# Imagen 3239: Clase predicha -> class_6
# Imagen 3240: Clase predicha -> class_4
# Imagen 3241: Clase predicha -> class_4
# Imagen 3242: Clase predicha -> class_1
# Imagen 3243: Clase predicha -> class_2
# Imagen 3244: Clase predicha -> class_3
# Imagen 3245: Clase predicha -> class_2
# Imagen 3246: Clase predicha -> class_6
# Imagen 3247: Clase predicha -> class_4
# Imagen 3248: Clase predicha -> class_2
# Imagen 3249: Clase predicha -> class_3
# Imagen 3250: Clase predicha -> class_3
# Imagen 3251: Clase predicha -> class_1
# Imagen 3252: Clase predicha -> class_2
# Imagen 3253: Clase predicha -> class_5
# Imagen 3254: Clase predicha -> class_6
# Imagen 3255: Clase predicha -> class_4
# Imagen 3256: Clase predicha -> class_3
# Imagen 3257: Clase predicha -> class_3
# Imagen 3258: Clase predicha -> class_5
# Imagen 3259: Clase predicha -> class_1
# Imagen 3260: Clase predicha -> class_6
# Imagen 3261: Clase predicha -> class_4
# Imagen 3262: Clase predicha -> class_4
# Imagen 3263: Clase predicha -> class_4
# Imagen 3264: Clase predicha -> class_5
# Imagen 3265: Clase predicha -> class_2
# Imagen 3266: Clase predicha -> class_5
# Imagen 3267: Clase predicha -> class_3
# Imagen 3268: Clase predicha -> class_2
# Imagen 3269: Clase predicha -> class_5
# Imagen 3270: Clase predicha -> class_2
# Imagen 3271: Clase predicha -> class_3
# Imagen 3272: Clase predicha -> class_5
# Imagen 3273: Clase predicha -> class_1
# Imagen 3274: Clase predicha -> class_4
# Imagen 3275: Clase predicha -> class_6
# Imagen 3276: Clase predicha -> class_5
# Imagen 3277: Clase predicha -> class_2
# Imagen 3278: Clase predicha -> class_5
# Imagen 3279: Clase predicha -> class_6
# Imagen 3280: Clase predicha -> class_3
# Imagen 3281: Clase predicha -> class_6
# Imagen 3282: Clase predicha -> class_5
# Imagen 3283: Clase predicha -> class_1
# Imagen 3284: Clase predicha -> class_5
# Imagen 3285: Clase predicha -> class_5
# Imagen 3286: Clase predicha -> class_5
# Imagen 3287: Clase predicha -> class_3
# Imagen 3288: Clase predicha -> class_5
# Imagen 3289: Clase predicha -> class_2
# Imagen 3290: Clase predicha -> class_3
# Imagen 3291: Clase predicha -> class_1
# Imagen 3292: Clase predicha -> class_3
# Imagen 3293: Clase predicha -> class_3
# Imagen 3294: Clase predicha -> class_1
# Imagen 3295: Clase predicha -> class_6
# Imagen 3296: Clase predicha -> class_5
# Imagen 3297: Clase predicha -> class_3
# Imagen 3298: Clase predicha -> class_4
# Imagen 3299: Clase predicha -> class_4
# Imagen 3300: Clase predicha -> class_6
# Imagen 3301: Clase predicha -> class_3
# Imagen 3302: Clase predicha -> class_3
# Imagen 3303: Clase predicha -> class_5
# Imagen 3304: Clase predicha -> class_4
# Imagen 3305: Clase predicha -> class_3
# Imagen 3306: Clase predicha -> class_4
# Imagen 3307: Clase predicha -> class_1
# Imagen 3308: Clase predicha -> class_4
# Imagen 3309: Clase predicha -> class_4
# Imagen 3310: Clase predicha -> class_1
# Imagen 3311: Clase predicha -> class_4
# Imagen 3312: Clase predicha -> class_4
# Imagen 3313: Clase predicha -> class_6
# Imagen 3314: Clase predicha -> class_6
# Imagen 3315: Clase predicha -> class_5
# Imagen 3316: Clase predicha -> class_5
# Imagen 3317: Clase predicha -> class_4
# Imagen 3318: Clase predicha -> class_3
# Imagen 3319: Clase predicha -> class_2
# Imagen 3320: Clase predicha -> class_4
# Imagen 3321: Clase predicha -> class_5
# Imagen 3322: Clase predicha -> class_1
# Imagen 3323: Clase predicha -> class_5
# Imagen 3324: Clase predicha -> class_3
# Imagen 3325: Clase predicha -> class_3
# Imagen 3326: Clase predicha -> class_1
# Imagen 3327: Clase predicha -> class_5
# Imagen 3328: Clase predicha -> class_5
# Imagen 3329: Clase predicha -> class_6
# Imagen 3330: Clase predicha -> class_4
# Imagen 3331: Clase predicha -> class_5
# Imagen 3332: Clase predicha -> class_5
# Imagen 3333: Clase predicha -> class_4
# Imagen 3334: Clase predicha -> class_5
# Imagen 3335: Clase predicha -> class_3
# Imagen 3336: Clase predicha -> class_2
# Imagen 3337: Clase predicha -> class_1
# Imagen 3338: Clase predicha -> class_2
# Imagen 3339: Clase predicha -> class_1
# Imagen 3340: Clase predicha -> class_2
# Imagen 3341: Clase predicha -> class_5
# Imagen 3342: Clase predicha -> class_2
# Imagen 3343: Clase predicha -> class_6
# Imagen 3344: Clase predicha -> class_4
# Imagen 3345: Clase predicha -> class_6
# Imagen 3346: Clase predicha -> class_4
# Imagen 3347: Clase predicha -> class_5
# Imagen 3348: Clase predicha -> class_1
# Imagen 3349: Clase predicha -> class_6
# Imagen 3350: Clase predicha -> class_4
# Imagen 3351: Clase predicha -> class_5
# Imagen 3352: Clase predicha -> class_4
# Imagen 3353: Clase predicha -> class_4
# Imagen 3354: Clase predicha -> class_5
# Imagen 3355: Clase predicha -> class_1
# Imagen 3356: Clase predicha -> class_3
# Imagen 3357: Clase predicha -> class_3
# Imagen 3358: Clase predicha -> class_1
# Imagen 3359: Clase predicha -> class_1
# Imagen 3360: Clase predicha -> class_4
# Imagen 3361: Clase predicha -> class_6
# Imagen 3362: Clase predicha -> class_3
# Imagen 3363: Clase predicha -> class_5
# Imagen 3364: Clase predicha -> class_4
# Imagen 3365: Clase predicha -> class_3
# Imagen 3366: Clase predicha -> class_6
# Imagen 3367: Clase predicha -> class_6
# Imagen 3368: Clase predicha -> class_2
# Imagen 3369: Clase predicha -> class_6
# Imagen 3370: Clase predicha -> class_4
# Imagen 3371: Clase predicha -> class_3
# Imagen 3372: Clase predicha -> class_2
# Imagen 3373: Clase predicha -> class_1
# Imagen 3374: Clase predicha -> class_6
# Imagen 3375: Clase predicha -> class_2
# Imagen 3376: Clase predicha -> class_3
# Imagen 3377: Clase predicha -> class_4
# Imagen 3378: Clase predicha -> class_5
# Imagen 3379: Clase predicha -> class_2
# Imagen 3380: Clase predicha -> class_3
# Imagen 3381: Clase predicha -> class_3
# Imagen 3382: Clase predicha -> class_4
# Imagen 3383: Clase predicha -> class_4
# Imagen 3384: Clase predicha -> class_2
# Imagen 3385: Clase predicha -> class_3
# Imagen 3386: Clase predicha -> class_1
# Imagen 3387: Clase predicha -> class_6
# Imagen 3388: Clase predicha -> class_4
# Imagen 3389: Clase predicha -> class_6
# Imagen 3390: Clase predicha -> class_3
# Imagen 3391: Clase predicha -> class_5
# Imagen 3392: Clase predicha -> class_4
# Imagen 3393: Clase predicha -> class_4
# Imagen 3394: Clase predicha -> class_1
# Imagen 3395: Clase predicha -> class_3
# Imagen 3396: Clase predicha -> class_4
# Imagen 3397: Clase predicha -> class_6
# Imagen 3398: Clase predicha -> class_6
# Imagen 3399: Clase predicha -> class_2
# Imagen 3400: Clase predicha -> class_5
# Imagen 3401: Clase predicha -> class_5
# Imagen 3402: Clase predicha -> class_2
# Imagen 3403: Clase predicha -> class_2
# Imagen 3404: Clase predicha -> class_2
# Imagen 3405: Clase predicha -> class_2
# Imagen 3406: Clase predicha -> class_1
# Imagen 3407: Clase predicha -> class_5
# Imagen 3408: Clase predicha -> class_1
# Imagen 3409: Clase predicha -> class_4
# Imagen 3410: Clase predicha -> class_4
# Imagen 3411: Clase predicha -> class_4
# Imagen 3412: Clase predicha -> class_6
# Imagen 3413: Clase predicha -> class_2
# Imagen 3414: Clase predicha -> class_5
# Imagen 3415: Clase predicha -> class_1
# Imagen 3416: Clase predicha -> class_4
# Imagen 3417: Clase predicha -> class_6
# Imagen 3418: Clase predicha -> class_2
# Imagen 3419: Clase predicha -> class_6
# Imagen 3420: Clase predicha -> class_4
# Imagen 3421: Clase predicha -> class_3
# Imagen 3422: Clase predicha -> class_3
# Imagen 3423: Clase predicha -> class_3
# Imagen 3424: Clase predicha -> class_6
# Imagen 3425: Clase predicha -> class_5
# Imagen 3426: Clase predicha -> class_1
# Imagen 3427: Clase predicha -> class_5
# Imagen 3428: Clase predicha -> class_4
# Imagen 3429: Clase predicha -> class_4
# Imagen 3430: Clase predicha -> class_6
# Imagen 3431: Clase predicha -> class_1
# Imagen 3432: Clase predicha -> class_4
# Imagen 3433: Clase predicha -> class_6
# Imagen 3434: Clase predicha -> class_5
# Imagen 3435: Clase predicha -> class_5
# Imagen 3436: Clase predicha -> class_6
# Imagen 3437: Clase predicha -> class_4
# Imagen 3438: Clase predicha -> class_5
# Imagen 3439: Clase predicha -> class_3
# Imagen 3440: Clase predicha -> class_4
# Imagen 3441: Clase predicha -> class_3
# Imagen 3442: Clase predicha -> class_2
# Imagen 3443: Clase predicha -> class_4
# Imagen 3444: Clase predicha -> class_6
# Imagen 3445: Clase predicha -> class_6
# Imagen 3446: Clase predicha -> class_4
# Imagen 3447: Clase predicha -> class_1
# Imagen 3448: Clase predicha -> class_6
# Imagen 3449: Clase predicha -> class_5
# Imagen 3450: Clase predicha -> class_1
# Imagen 3451: Clase predicha -> class_3
# Imagen 3452: Clase predicha -> class_3
# Imagen 3453: Clase predicha -> class_4
# Imagen 3454: Clase predicha -> class_4
# Imagen 3455: Clase predicha -> class_3
# Imagen 3456: Clase predicha -> class_6
# Imagen 3457: Clase predicha -> class_1
# Imagen 3458: Clase predicha -> class_6
# Imagen 3459: Clase predicha -> class_2
# Imagen 3460: Clase predicha -> class_5
# Imagen 3461: Clase predicha -> class_4
# Imagen 3462: Clase predicha -> class_6
# Imagen 3463: Clase predicha -> class_2
# Imagen 3464: Clase predicha -> class_3
# Imagen 3465: Clase predicha -> class_1
# Imagen 3466: Clase predicha -> class_3
# Imagen 3467: Clase predicha -> class_3
# Imagen 3468: Clase predicha -> class_4
# Imagen 3469: Clase predicha -> class_3
# Imagen 3470: Clase predicha -> class_3
# Imagen 3471: Clase predicha -> class_5
# Imagen 3472: Clase predicha -> class_3
# Imagen 3473: Clase predicha -> class_2
# Imagen 3474: Clase predicha -> class_1
# Imagen 3475: Clase predicha -> class_3
# Imagen 3476: Clase predicha -> class_4
# Imagen 3477: Clase predicha -> class_6
# Imagen 3478: Clase predicha -> class_2
# Imagen 3479: Clase predicha -> class_1
# Imagen 3480: Clase predicha -> class_6
# Imagen 3481: Clase predicha -> class_5
# Imagen 3482: Clase predicha -> class_4
# Imagen 3483: Clase predicha -> class_2
# Imagen 3484: Clase predicha -> class_2
# Imagen 3485: Clase predicha -> class_5
# Imagen 3486: Clase predicha -> class_1
# Imagen 3487: Clase predicha -> class_1
# Imagen 3488: Clase predicha -> class_6
# Imagen 3489: Clase predicha -> class_4
# Imagen 3490: Clase predicha -> class_6
# Imagen 3491: Clase predicha -> class_4
# Imagen 3492: Clase predicha -> class_5
# Imagen 3493: Clase predicha -> class_4
# Imagen 3494: Clase predicha -> class_5
# Imagen 3495: Clase predicha -> class_1
# Imagen 3496: Clase predicha -> class_5
# Imagen 3497: Clase predicha -> class_4
# Imagen 3498: Clase predicha -> class_6
# Imagen 3499: Clase predicha -> class_3
# Imagen 3500: Clase predicha -> class_6
# Imagen 3501: Clase predicha -> class_5
# Imagen 3502: Clase predicha -> class_6
# Imagen 3503: Clase predicha -> class_3
# Imagen 3504: Clase predicha -> class_4
# Imagen 3505: Clase predicha -> class_3
# Imagen 3506: Clase predicha -> class_6
# Imagen 3507: Clase predicha -> class_4
# Imagen 3508: Clase predicha -> class_3
# Imagen 3509: Clase predicha -> class_5
# Imagen 3510: Clase predicha -> class_4
# Imagen 3511: Clase predicha -> class_4
# Imagen 3512: Clase predicha -> class_2
# Imagen 3513: Clase predicha -> class_4
# Imagen 3514: Clase predicha -> class_4
# Imagen 3515: Clase predicha -> class_6
# Imagen 3516: Clase predicha -> class_4
# Imagen 3517: Clase predicha -> class_4
# Imagen 3518: Clase predicha -> class_4
# Imagen 3519: Clase predicha -> class_2
# Imagen 3520: Clase predicha -> class_3
# Imagen 3521: Clase predicha -> class_3
# Imagen 3522: Clase predicha -> class_3
# Imagen 3523: Clase predicha -> class_6
# Imagen 3524: Clase predicha -> class_3
# Imagen 3525: Clase predicha -> class_6
# Imagen 3526: Clase predicha -> class_5
# Imagen 3527: Clase predicha -> class_2
# Imagen 3528: Clase predicha -> class_1
# Imagen 3529: Clase predicha -> class_4
# Imagen 3530: Clase predicha -> class_2
# ...
# Imagen 6892: Clase predicha -> class_5
# Imagen 6893: Clase predicha -> class_4
# Imagen 6894: Clase predicha -> class_4
# Imagen 6895: Clase predicha -> class_5
# Imagen 6896: Clase predicha -> class_6
# Imagen 6897: Clase predicha -> class_4
# Imagen 6898: Clase predicha -> class_4
# Imagen 6899: Clase predicha -> class_1
# Imagen 6900: Clase predicha -> class_1
# Imagen 6901: Clase predicha -> class_3
# Imagen 6902: Clase predicha -> class_6
# Imagen 6903: Clase predicha -> class_3
# Imagen 6904: Clase predicha -> class_3
# Imagen 6905: Clase predicha -> class_3
# Imagen 6906: Clase predicha -> class_1
# Imagen 6907: Clase predicha -> class_4
# Imagen 6908: Clase predicha -> class_4
# Imagen 6909: Clase predicha -> class_5
# Imagen 6910: Clase predicha -> class_1
# Imagen 6911: Clase predicha -> class_6
# Imagen 6912: Clase predicha -> class_1
# Imagen 6913: Clase predicha -> class_4
# Imagen 6914: Clase predicha -> class_3
# Imagen 6915: Clase predicha -> class_2
# Imagen 6916: Clase predicha -> class_2
# Imagen 6917: Clase predicha -> class_4
# Imagen 6918: Clase predicha -> class_5
# Imagen 6919: Clase predicha -> class_1
# Imagen 6920: Clase predicha -> class_2
# Imagen 6921: Clase predicha -> class_5
# Imagen 6922: Clase predicha -> class_3
# Imagen 6923: Clase predicha -> class_4
# Imagen 6924: Clase predicha -> class_6
# Imagen 6925: Clase predicha -> class_2
# Imagen 6926: Clase predicha -> class_3
# Imagen 6927: Clase predicha -> class_1
# Imagen 6928: Clase predicha -> class_5
# Imagen 6929: Clase predicha -> class_2
# Imagen 6930: Clase predicha -> class_3
# Imagen 6931: Clase predicha -> class_4
# Imagen 6932: Clase predicha -> class_3
# Imagen 6933: Clase predicha -> class_3
# Imagen 6934: Clase predicha -> class_4
# Imagen 6935: Clase predicha -> class_4
# Imagen 6936: Clase predicha -> class_4
# Imagen 6937: Clase predicha -> class_1
# Imagen 6938: Clase predicha -> class_5
# Imagen 6939: Clase predicha -> class_5
# Imagen 6940: Clase predicha -> class_3
# Imagen 6941: Clase predicha -> class_5
# Imagen 6942: Clase predicha -> class_1
# Imagen 6943: Clase predicha -> class_3
# Imagen 6944: Clase predicha -> class_2
# Imagen 6945: Clase predicha -> class_5
# Imagen 6946: Clase predicha -> class_6
# Imagen 6947: Clase predicha -> class_3
# Imagen 6948: Clase predicha -> class_6
# Imagen 6949: Clase predicha -> class_4
# Imagen 6950: Clase predicha -> class_6
# Imagen 6951: Clase predicha -> class_3
# Imagen 6952: Clase predicha -> class_3
# Imagen 6953: Clase predicha -> class_5
# Imagen 6954: Clase predicha -> class_3
# Imagen 6955: Clase predicha -> class_1
# Imagen 6956: Clase predicha -> class_2
# Imagen 6957: Clase predicha -> class_6
# Imagen 6958: Clase predicha -> class_2
# Imagen 6959: Clase predicha -> class_5
# Imagen 6960: Clase predicha -> class_3
# Imagen 6961: Clase predicha -> class_5
# Imagen 6962: Clase predicha -> class_4
# Imagen 6963: Clase predicha -> class_2
# Imagen 6964: Clase predicha -> class_6
# Imagen 6965: Clase predicha -> class_2
# Imagen 6966: Clase predicha -> class_4
# Imagen 6967: Clase predicha -> class_1
# Imagen 6968: Clase predicha -> class_1
# Imagen 6969: Clase predicha -> class_1
# Imagen 6970: Clase predicha -> class_5
# Imagen 6971: Clase predicha -> class_4
# Imagen 6972: Clase predicha -> class_5
# Imagen 6973: Clase predicha -> class_4
# Imagen 6974: Clase predicha -> class_6
# Imagen 6975: Clase predicha -> class_6
# Imagen 6976: Clase predicha -> class_1
# Imagen 6977: Clase predicha -> class_1
# Imagen 6978: Clase predicha -> class_3
# Imagen 6979: Clase predicha -> class_6
# Imagen 6980: Clase predicha -> class_6
# Imagen 6981: Clase predicha -> class_3
# Imagen 6982: Clase predicha -> class_4
# Imagen 6983: Clase predicha -> class_5
# Imagen 6984: Clase predicha -> class_4
# Imagen 6985: Clase predicha -> class_1
# Imagen 6986: Clase predicha -> class_2
# Imagen 6987: Clase predicha -> class_2
# Imagen 6988: Clase predicha -> class_6
# Imagen 6989: Clase predicha -> class_4
# Imagen 6990: Clase predicha -> class_6
# Imagen 6991: Clase predicha -> class_5
# Imagen 6992: Clase predicha -> class_2
# Imagen 6993: Clase predicha -> class_5
# Imagen 6994: Clase predicha -> class_4
# Imagen 6995: Clase predicha -> class_5
# Imagen 6996: Clase predicha -> class_5
# Imagen 6997: Clase predicha -> class_5
# Imagen 6998: Clase predicha -> class_5
# Imagen 6999: Clase predicha -> class_4
# Imagen 7000: Clase predicha -> class_5
# Imagen 7001: Clase predicha -> class_6
# Imagen 7002: Clase predicha -> class_2
# Imagen 7003: Clase predicha -> class_1
# Imagen 7004: Clase predicha -> class_6
# Imagen 7005: Clase predicha -> class_6
# Imagen 7006: Clase predicha -> class_1
# Imagen 7007: Clase predicha -> class_5
# Imagen 7008: Clase predicha -> class_6
# Imagen 7009: Clase predicha -> class_4
# Imagen 7010: Clase predicha -> class_3
# Imagen 7011: Clase predicha -> class_3
# Imagen 7012: Clase predicha -> class_6
# Imagen 7013: Clase predicha -> class_5
# Imagen 7014: Clase predicha -> class_5
# Imagen 7015: Clase predicha -> class_6
# Imagen 7016: Clase predicha -> class_4
# Imagen 7017: Clase predicha -> class_6
# Imagen 7018: Clase predicha -> class_6
# Imagen 7019: Clase predicha -> class_6
# Imagen 7020: Clase predicha -> class_2
# Imagen 7021: Clase predicha -> class_5
# Imagen 7022: Clase predicha -> class_6
# Imagen 7023: Clase predicha -> class_3
# Imagen 7024: Clase predicha -> class_3
# Imagen 7025: Clase predicha -> class_6
# Imagen 7026: Clase predicha -> class_3
# Imagen 7027: Clase predicha -> class_5
# Imagen 7028: Clase predicha -> class_4
# Imagen 7029: Clase predicha -> class_5
# Imagen 7030: Clase predicha -> class_1
# Imagen 7031: Clase predicha -> class_5
# Imagen 7032: Clase predicha -> class_2
# Imagen 7033: Clase predicha -> class_1
# Imagen 7034: Clase predicha -> class_3
# Imagen 7035: Clase predicha -> class_1
# Imagen 7036: Clase predicha -> class_3
# Imagen 7037: Clase predicha -> class_3
# Imagen 7038: Clase predicha -> class_1
# Imagen 7039: Clase predicha -> class_3
# Imagen 7040: Clase predicha -> class_4
# Imagen 7041: Clase predicha -> class_1
# Imagen 7042: Clase predicha -> class_3
# Imagen 7043: Clase predicha -> class_6
# Imagen 7044: Clase predicha -> class_6
# Imagen 7045: Clase predicha -> class_5
# Imagen 7046: Clase predicha -> class_1
# Imagen 7047: Clase predicha -> class_1
# Imagen 7048: Clase predicha -> class_2
# Imagen 7049: Clase predicha -> class_2
# Imagen 7050: Clase predicha -> class_3
# Imagen 7051: Clase predicha -> class_6
# Imagen 7052: Clase predicha -> class_6
# Imagen 7053: Clase predicha -> class_1
# Imagen 7054: Clase predicha -> class_5
# Imagen 7055: Clase predicha -> class_5
# Imagen 7056: Clase predicha -> class_5
# Imagen 7057: Clase predicha -> class_1
# Imagen 7058: Clase predicha -> class_1
# Imagen 7059: Clase predicha -> class_3
# Imagen 7060: Clase predicha -> class_1
# Imagen 7061: Clase predicha -> class_6
# Imagen 7062: Clase predicha -> class_2
# Imagen 7063: Clase predicha -> class_5
# Imagen 7064: Clase predicha -> class_3
# Imagen 7065: Clase predicha -> class_5
# Imagen 7066: Clase predicha -> class_5
# Imagen 7067: Clase predicha -> class_3
# Imagen 7068: Clase predicha -> class_1
# Imagen 7069: Clase predicha -> class_5
# Imagen 7070: Clase predicha -> class_3
# Imagen 7071: Clase predicha -> class_4
# Imagen 7072: Clase predicha -> class_6
# Imagen 7073: Clase predicha -> class_6
# Imagen 7074: Clase predicha -> class_4
# Imagen 7075: Clase predicha -> class_3
# Imagen 7076: Clase predicha -> class_2
# Imagen 7077: Clase predicha -> class_4
# Imagen 7078: Clase predicha -> class_5
# Imagen 7079: Clase predicha -> class_2
# Imagen 7080: Clase predicha -> class_3
# Imagen 7081: Clase predicha -> class_5
# Imagen 7082: Clase predicha -> class_3
# Imagen 7083: Clase predicha -> class_2
# Imagen 7084: Clase predicha -> class_6
# Imagen 7085: Clase predicha -> class_6
# Imagen 7086: Clase predicha -> class_3
# Imagen 7087: Clase predicha -> class_4
# Imagen 7088: Clase predicha -> class_4
# Imagen 7089: Clase predicha -> class_3
# Imagen 7090: Clase predicha -> class_5
# Imagen 7091: Clase predicha -> class_1
# Imagen 7092: Clase predicha -> class_3
# Imagen 7093: Clase predicha -> class_5
# Imagen 7094: Clase predicha -> class_4
# Imagen 7095: Clase predicha -> class_3
# Imagen 7096: Clase predicha -> class_5
# Imagen 7097: Clase predicha -> class_2
# Imagen 7098: Clase predicha -> class_2
# Imagen 7099: Clase predicha -> class_3
# Imagen 7100: Clase predicha -> class_3
# Imagen 7101: Clase predicha -> class_5
# Imagen 7102: Clase predicha -> class_3
# Imagen 7103: Clase predicha -> class_6
# Imagen 7104: Clase predicha -> class_5
# Imagen 7105: Clase predicha -> class_3
# Imagen 7106: Clase predicha -> class_6
# Imagen 7107: Clase predicha -> class_3
# Imagen 7108: Clase predicha -> class_4
# Imagen 7109: Clase predicha -> class_2
# Imagen 7110: Clase predicha -> class_1
# Imagen 7111: Clase predicha -> class_2
# Imagen 7112: Clase predicha -> class_1
# Imagen 7113: Clase predicha -> class_1
# Imagen 7114: Clase predicha -> class_2
# Imagen 7115: Clase predicha -> class_5
# Imagen 7116: Clase predicha -> class_5
# Imagen 7117: Clase predicha -> class_4
# Imagen 7118: Clase predicha -> class_1
# Imagen 7119: Clase predicha -> class_6
# Imagen 7120: Clase predicha -> class_2
# Imagen 7121: Clase predicha -> class_6
# Imagen 7122: Clase predicha -> class_4
# Imagen 7123: Clase predicha -> class_2
# Imagen 7124: Clase predicha -> class_1
# Imagen 7125: Clase predicha -> class_3
# Imagen 7126: Clase predicha -> class_1
# Imagen 7127: Clase predicha -> class_4
# Imagen 7128: Clase predicha -> class_5
# Imagen 7129: Clase predicha -> class_5
# Imagen 7130: Clase predicha -> class_3
# Imagen 7131: Clase predicha -> class_5
# Imagen 7132: Clase predicha -> class_3
# Imagen 7133: Clase predicha -> class_3
# Imagen 7134: Clase predicha -> class_5
# Imagen 7135: Clase predicha -> class_4
# Imagen 7136: Clase predicha -> class_1
# Imagen 7137: Clase predicha -> class_1
# Imagen 7138: Clase predicha -> class_6
# Imagen 7139: Clase predicha -> class_4
# Imagen 7140: Clase predicha -> class_1
# Imagen 7141: Clase predicha -> class_2
# Imagen 7142: Clase predicha -> class_6
# Imagen 7143: Clase predicha -> class_4
# Imagen 7144: Clase predicha -> class_4
# Imagen 7145: Clase predicha -> class_3
# Imagen 7146: Clase predicha -> class_1
# Imagen 7147: Clase predicha -> class_5
# Imagen 7148: Clase predicha -> class_3
# Imagen 7149: Clase predicha -> class_5
# Imagen 7150: Clase predicha -> class_6
# Imagen 7151: Clase predicha -> class_3
# Imagen 7152: Clase predicha -> class_4
# Imagen 7153: Clase predicha -> class_4
# Imagen 7154: Clase predicha -> class_3
# Imagen 7155: Clase predicha -> class_4
# Imagen 7156: Clase predicha -> class_3
# Imagen 7157: Clase predicha -> class_4
# Imagen 7158: Clase predicha -> class_5
# Imagen 7159: Clase predicha -> class_6
# Imagen 7160: Clase predicha -> class_2
# Imagen 7161: Clase predicha -> class_5
# Imagen 7162: Clase predicha -> class_5
# Imagen 7163: Clase predicha -> class_4
# Imagen 7164: Clase predicha -> class_6
# Imagen 7165: Clase predicha -> class_5
# Imagen 7166: Clase predicha -> class_2
# Imagen 7167: Clase predicha -> class_2
# Imagen 7168: Clase predicha -> class_5
# Imagen 7169: Clase predicha -> class_5
# Imagen 7170: Clase predicha -> class_3
# Imagen 7171: Clase predicha -> class_3
# Imagen 7172: Clase predicha -> class_2
# Imagen 7173: Clase predicha -> class_4
# Imagen 7174: Clase predicha -> class_6
# Imagen 7175: Clase predicha -> class_6
# Imagen 7176: Clase predicha -> class_2
# Imagen 7177: Clase predicha -> class_5
# Imagen 7178: Clase predicha -> class_3
# Imagen 7179: Clase predicha -> class_5
# Imagen 7180: Clase predicha -> class_6
# Imagen 7181: Clase predicha -> class_3
# Imagen 7182: Clase predicha -> class_4
# Imagen 7183: Clase predicha -> class_1
# Imagen 7184: Clase predicha -> class_3
# Imagen 7185: Clase predicha -> class_1
# Imagen 7186: Clase predicha -> class_4
# Imagen 7187: Clase predicha -> class_2
# Imagen 7188: Clase predicha -> class_5
# Imagen 7189: Clase predicha -> class_4
# Imagen 7190: Clase predicha -> class_6
# Imagen 7191: Clase predicha -> class_3
# Imagen 7192: Clase predicha -> class_3
# Imagen 7193: Clase predicha -> class_3
# Imagen 7194: Clase predicha -> class_3
# Imagen 7195: Clase predicha -> class_3
# Imagen 7196: Clase predicha -> class_2
# Imagen 7197: Clase predicha -> class_1
# Imagen 7198: Clase predicha -> class_1
# Imagen 7199: Clase predicha -> class_5
# Imagen 7200: Clase predicha -> class_4
# Imagen 7201: Clase predicha -> class_3
# Imagen 7202: Clase predicha -> class_4
# Imagen 7203: Clase predicha -> class_1
# Imagen 7204: Clase predicha -> class_1
# Imagen 7205: Clase predicha -> class_1
# Imagen 7206: Clase predicha -> class_6
# Imagen 7207: Clase predicha -> class_4
# Imagen 7208: Clase predicha -> class_2
# Imagen 7209: Clase predicha -> class_6
# Imagen 7210: Clase predicha -> class_6
# Imagen 7211: Clase predicha -> class_4
# Imagen 7212: Clase predicha -> class_3
# Imagen 7213: Clase predicha -> class_4
# Imagen 7214: Clase predicha -> class_3
# Imagen 7215: Clase predicha -> class_1
# Imagen 7216: Clase predicha -> class_3
# Imagen 7217: Clase predicha -> class_2
# Imagen 7218: Clase predicha -> class_6
# Imagen 7219: Clase predicha -> class_2
# Imagen 7220: Clase predicha -> class_1
# Imagen 7221: Clase predicha -> class_4
# Imagen 7222: Clase predicha -> class_5
# Imagen 7223: Clase predicha -> class_3
# Imagen 7224: Clase predicha -> class_2
# Imagen 7225: Clase predicha -> class_5
# Imagen 7226: Clase predicha -> class_2
# Imagen 7227: Clase predicha -> class_5
# Imagen 7228: Clase predicha -> class_2
# Imagen 7229: Clase predicha -> class_4
# Imagen 7230: Clase predicha -> class_4
# Imagen 7231: Clase predicha -> class_4
# Imagen 7232: Clase predicha -> class_1
# Imagen 7233: Clase predicha -> class_6
# Imagen 7234: Clase predicha -> class_6
# Imagen 7235: Clase predicha -> class_5
# Imagen 7236: Clase predicha -> class_1
# Imagen 7237: Clase predicha -> class_6
# Imagen 7238: Clase predicha -> class_3
# Imagen 7239: Clase predicha -> class_4
# Imagen 7240: Clase predicha -> class_4
# Imagen 7241: Clase predicha -> class_5
# Imagen 7242: Clase predicha -> class_3
# Imagen 7243: Clase predicha -> class_4
# Imagen 7244: Clase predicha -> class_1
# Imagen 7245: Clase predicha -> class_5
# Imagen 7246: Clase predicha -> class_6
# Imagen 7247: Clase predicha -> class_3
# Imagen 7248: Clase predicha -> class_5
# Imagen 7249: Clase predicha -> class_5
# Imagen 7250: Clase predicha -> class_1
# Imagen 7251: Clase predicha -> class_6
# Imagen 7252: Clase predicha -> class_4
# Imagen 7253: Clase predicha -> class_5
# Imagen 7254: Clase predicha -> class_4
# Imagen 7255: Clase predicha -> class_2
# Imagen 7256: Clase predicha -> class_6
# Imagen 7257: Clase predicha -> class_4
# Imagen 7258: Clase predicha -> class_5
# Imagen 7259: Clase predicha -> class_5
# Imagen 7260: Clase predicha -> class_4
# Imagen 7261: Clase predicha -> class_1
# Imagen 7262: Clase predicha -> class_5
# Imagen 7263: Clase predicha -> class_6
# Imagen 7264: Clase predicha -> class_5
# Imagen 7265: Clase predicha -> class_6
# Imagen 7266: Clase predicha -> class_4
# Imagen 7267: Clase predicha -> class_6
# Imagen 7268: Clase predicha -> class_4
# Imagen 7269: Clase predicha -> class_1
# Imagen 7270: Clase predicha -> class_6
# Imagen 7271: Clase predicha -> class_1
# Imagen 7272: Clase predicha -> class_3
# Imagen 7273: Clase predicha -> class_1
# Imagen 7274: Clase predicha -> class_1
# Imagen 7275: Clase predicha -> class_5
# Imagen 7276: Clase predicha -> class_3
# Imagen 7277: Clase predicha -> class_6
# Imagen 7278: Clase predicha -> class_4
# Imagen 7279: Clase predicha -> class_1
# Imagen 7280: Clase predicha -> class_4
# Imagen 7281: Clase predicha -> class_4
# Imagen 7282: Clase predicha -> class_6
# Imagen 7283: Clase predicha -> class_1
# Imagen 7284: Clase predicha -> class_4
# Imagen 7285: Clase predicha -> class_3
# Imagen 7286: Clase predicha -> class_4
# Imagen 7287: Clase predicha -> class_5
# Imagen 7288: Clase predicha -> class_1
# Imagen 7289: Clase predicha -> class_6
# Imagen 7290: Clase predicha -> class_3
# Imagen 7291: Clase predicha -> class_3
# Imagen 7292: Clase predicha -> class_3
# Imagen 7293: Clase predicha -> class_3
# Imagen 7294: Clase predicha -> class_5
# Imagen 7295: Clase predicha -> class_3
# Imagen 7296: Clase predicha -> class_5
# Imagen 7297: Clase predicha -> class_3
# Imagen 7298: Clase predicha -> class_4
# Imagen 7299: Clase predicha -> class_4
# Imagen 7300: Clase predicha -> class_3
# Imagen 7301: Clase predicha -> class_3

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# Función para cargar las imágenes desde una carpeta
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder, filename), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            images.append(img)
    return images

# Cargar el modelo entrenado
model = load_model('/content/modelo_entrenado.h5')

# Ruta de la carpeta que contiene las imágenes que deseas clasificar
pred_folder = '/content/seg_pred/seg_pred'

# Cargar las imágenes
pred_images = load_images_from_folder(pred_folder)

# Preprocesar las imágenes
def preprocess_images(images):
    processed_images = []
    for img in images:
        resized_img = cv2.resize(img, (100, 100))
        processed_images.append(resized_img)
    return processed_images

pred_images_processed = preprocess_images(pred_images)

# Convertir las imágenes a matrices numpy y normalizar los valores de los píxeles
X_pred = np.array(pred_images_processed) / 255.0

# Cargar el diccionario label_to_index utilizado durante el entrenamiento
label_to_index = {0: 'class_1', 1: 'class_2', 2: 'class_3', 3: 'class_4', 4: 'class_5', 5: 'class_6'}

# Realizar predicciones en las imágenes cargadas
y_pred = model.predict(X_pred.reshape(-1, 100, 100, 1))

# Obtener las etiquetas predichas para cada imagen
predicted_labels = np.argmax(y_pred, axis=1)

# Decodificar las etiquetas numéricas a etiquetas de clase
predicted_classes = [label_to_index[label] for label in predicted_labels]

# Visualizar algunas de las imágenes junto con las etiquetas predichas
num_images_to_show = 5
selected_indices = np.random.choice(len(pred_images), num_images_to_show, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(selected_indices):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(pred_images[idx], cmap='gray')
    plt.title(f"Predicha: {predicted_classes[idx]}")
    plt.axis('off')

plt.show()
# Out:
# 229/229 [==============================] - 11s 48ms/step
